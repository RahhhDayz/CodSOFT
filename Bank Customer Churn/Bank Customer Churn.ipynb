# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/Users/rahulsharma/GitHub/CodSOFT/Bank Customer Churn/Churn_Modelling.csv')

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
df.drop(columns = ['RowNumber','CustomerId','Surname'], inplace= True )

# %%
df.isnull().sum()
# Out:
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
df.corr()
# Out:
#                  CreditScore       Age    Tenure   Balance  NumOfProducts  \
# CreditScore         1.000000 -0.003965  0.000842  0.006268       0.012238
# Age                -0.003965  1.000000 -0.009997  0.028308      -0.030680
# Tenure              0.000842 -0.009997  1.000000 -0.012254       0.013444
# Balance             0.006268  0.028308 -0.012254  1.000000      -0.304180
# NumOfProducts       0.012238 -0.030680  0.013444 -0.304180       1.000000
# HasCrCard          -0.005458 -0.011721  0.022583 -0.014858       0.003183
# IsActiveMember      0.025651  0.085472 -0.028362 -0.010084       0.009612
# EstimatedSalary    -0.001384 -0.007201  0.007784  0.012797       0.014204
# Exited             -0.027094  0.285323 -0.014001  0.118533      -0.047820
#
#                  HasCrCard  IsActiveMember  EstimatedSalary    Exited
# CreditScore      -0.005458        0.025651        -0.001384 -0.027094
# Age              -0.011721        0.085472        -0.007201  0.285323
# Tenure            0.022583       -0.028362         0.007784 -0.014001
# Balance          -0.014858       -0.010084         0.012797  0.118533
# NumOfProducts     0.003183        0.009612         0.014204 -0.047820
# HasCrCard         1.000000       -0.011866        -0.009933 -0.007138
# IsActiveMember   -0.011866        1.000000        -0.011421 -0.156128
# EstimatedSalary  -0.009933       -0.011421         1.000000  0.012097
# Exited           -0.007138       -0.156128         0.012097  1.000000

# %%
import seaborn as sns

corr_matrix=df.corr()
 

plt.figure(1, figsize=(10,5))
sns.heatmap(corr_matrix, cmap='BrBG', center=0, annot=True)
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   CreditScore      10000 non-null  int64
#  1   Geography        10000 non-null  object
#  2   Gender           10000 non-null  object
#  3   Age              10000 non-null  int64
#  4   Tenure           10000 non-null  int64
#  5   Balance          10000 non-null  float64
#  6   NumOfProducts    10000 non-null  int64
#  7   HasCrCard        10000 non-null  int64
#  8   IsActiveMember   10000 non-null  int64
#  9   EstimatedSalary  10000 non-null  float64
#  10  Exited           10000 non-null  int64
# dtypes: float64(2), int64(7), object(2)
# memory usage: 859.5+ KB

# %%
from sklearn import preprocessing
lable_encode=preprocessing.LabelEncoder()
df['Gender']=lable_encode.fit_transform(df['Gender'])
df['Geography']=lable_encode.fit_transform(df['Geography'])

# %%
df.head()
# Out:
#    CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619          0       0   42       2       0.00              1
# 1          608          2       0   41       1   83807.86              1
# 2          502          0       0   42       8  159660.80              3
# 3          699          0       0   39       1       0.00              2
# 4          850          2       0   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
X=df.drop(columns=['Exited'])
y=df['Exited']

# %% [markdown]
# ## Splitting the data

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.25,random_state=3)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %% [markdown]
# ## Building The Model

# %%
import tensorflow 
from tensorflow import keras
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense

# %%
classifier=Sequential()
# Out:
# 2023-08-13 12:53:39.508284: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M1 Pro
# 2023-08-13 12:53:39.508312: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2023-08-13 12:53:39.508318: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2023-08-13 12:53:39.508391: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:303] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-08-13 12:53:39.508426: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:269] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)

# %%
classifier.add(Dense(6, activation = 'relu',input_dim=10))
classifier.add(Dense(6,activation='relu'))
classifier.add(Dense(1,activation='sigmoid'))

# %%
classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
classifier.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 6)                 66
#
#  dense_1 (Dense)             (None, 6)                 42
#
#  dense_2 (Dense)             (None, 1)                 7
#
# =================================================================
# Total params: 115 (460.00 Byte)
# Trainable params: 115 (460.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
history = classifier.fit(X_train,y_train,batch_size=10,epochs=100,verbose=1,validation_split=0.25)
# Out:
# Epoch 1/100
# 2023-08-13 12:53:57.252220: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 563/563 [==============================] - ETA: 0s - loss: 0.5966 - accuracy: 0.7124
# 2023-08-13 12:54:03.288658: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 563/563 [==============================] - 7s 9ms/step - loss: 0.5966 - accuracy: 0.7124 - val_loss: 0.4531 - val_accuracy: 0.8128
# Epoch 2/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.4422 - accuracy: 0.8087 - val_loss: 0.4372 - val_accuracy: 0.8112
# Epoch 3/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4366 - accuracy: 0.8123 - val_loss: 0.4368 - val_accuracy: 0.8117
# Epoch 4/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4367 - accuracy: 0.8084 - val_loss: 0.4357 - val_accuracy: 0.8165
# Epoch 5/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4373 - accuracy: 0.8076 - val_loss: 0.4337 - val_accuracy: 0.8080
# Epoch 6/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4376 - accuracy: 0.8044 - val_loss: 0.4385 - val_accuracy: 0.8080
# Epoch 7/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4391 - accuracy: 0.8073 - val_loss: 0.4386 - val_accuracy: 0.8069
# Epoch 8/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4404 - accuracy: 0.8050 - val_loss: 0.4414 - val_accuracy: 0.8075
# Epoch 9/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4399 - accuracy: 0.8089 - val_loss: 0.4357 - val_accuracy: 0.8091
# Epoch 10/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4404 - accuracy: 0.8087 - val_loss: 0.4347 - val_accuracy: 0.8069
# Epoch 11/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4399 - accuracy: 0.8107 - val_loss: 0.4348 - val_accuracy: 0.8117
# Epoch 12/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4403 - accuracy: 0.8069 - val_loss: 0.4366 - val_accuracy: 0.8144
# Epoch 13/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4419 - accuracy: 0.8100 - val_loss: 0.4510 - val_accuracy: 0.8048
# Epoch 14/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4425 - accuracy: 0.8116 - val_loss: 0.4534 - val_accuracy: 0.8187
# Epoch 15/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4467 - accuracy: 0.8114 - val_loss: 0.4475 - val_accuracy: 0.8096
# Epoch 16/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4430 - accuracy: 0.8084 - val_loss: 0.4399 - val_accuracy: 0.8133
# Epoch 17/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4468 - accuracy: 0.8073 - val_loss: 0.4438 - val_accuracy: 0.8117
# Epoch 18/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4518 - accuracy: 0.8076 - val_loss: 0.4550 - val_accuracy: 0.8085
# Epoch 19/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4486 - accuracy: 0.8123 - val_loss: 0.4412 - val_accuracy: 0.8101
# Epoch 20/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4568 - accuracy: 0.8044 - val_loss: 0.4521 - val_accuracy: 0.8080
# Epoch 21/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4506 - accuracy: 0.8094 - val_loss: 0.4441 - val_accuracy: 0.8117
# Epoch 22/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4530 - accuracy: 0.8050 - val_loss: 0.4707 - val_accuracy: 0.7995
# Epoch 23/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4592 - accuracy: 0.8050 - val_loss: 0.4627 - val_accuracy: 0.8155
# Epoch 24/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4644 - accuracy: 0.8043 - val_loss: 0.4368 - val_accuracy: 0.8085
# Epoch 25/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4613 - accuracy: 0.7982 - val_loss: 0.4540 - val_accuracy: 0.8085
# Epoch 26/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4631 - accuracy: 0.8062 - val_loss: 0.4445 - val_accuracy: 0.8069
# Epoch 27/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4565 - accuracy: 0.8046 - val_loss: 0.4445 - val_accuracy: 0.8096
# Epoch 28/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4613 - accuracy: 0.8044 - val_loss: 0.4403 - val_accuracy: 0.8069
# Epoch 29/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4662 - accuracy: 0.8046 - val_loss: 0.5050 - val_accuracy: 0.8208
# Epoch 30/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4697 - accuracy: 0.8014 - val_loss: 0.4378 - val_accuracy: 0.8080
# Epoch 31/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4825 - accuracy: 0.7979 - val_loss: 0.4575 - val_accuracy: 0.8160
# Epoch 32/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4826 - accuracy: 0.7945 - val_loss: 0.4426 - val_accuracy: 0.8149
# Epoch 33/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4655 - accuracy: 0.8018 - val_loss: 0.4977 - val_accuracy: 0.7835
# Epoch 34/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4733 - accuracy: 0.8002 - val_loss: 0.4384 - val_accuracy: 0.8080
# Epoch 35/100
# 563/563 [==============================] - 4s 7ms/step - loss: 0.4746 - accuracy: 0.8034 - val_loss: 0.4793 - val_accuracy: 0.7957
# Epoch 36/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4670 - accuracy: 0.8030 - val_loss: 0.4531 - val_accuracy: 0.8091
# Epoch 37/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4829 - accuracy: 0.7966 - val_loss: 0.4789 - val_accuracy: 0.8229
# Epoch 38/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4821 - accuracy: 0.8053 - val_loss: 0.4571 - val_accuracy: 0.8037
# Epoch 39/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.4840 - accuracy: 0.7975 - val_loss: 0.4582 - val_accuracy: 0.8032
# Epoch 40/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4758 - accuracy: 0.8027 - val_loss: 0.4383 - val_accuracy: 0.8075
# Epoch 41/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.5083 - accuracy: 0.7956 - val_loss: 0.6082 - val_accuracy: 0.7243
# Epoch 42/100
# 563/563 [==============================] - 7s 12ms/step - loss: 0.4950 - accuracy: 0.8014 - val_loss: 0.5168 - val_accuracy: 0.7760
# Epoch 43/100
# 563/563 [==============================] - 7s 12ms/step - loss: 0.4868 - accuracy: 0.7979 - val_loss: 0.4381 - val_accuracy: 0.8096
# Epoch 44/100
# 563/563 [==============================] - 7s 12ms/step - loss: 0.4963 - accuracy: 0.7975 - val_loss: 0.4525 - val_accuracy: 0.8011
# Epoch 45/100
# 563/563 [==============================] - 7s 12ms/step - loss: 0.5009 - accuracy: 0.7950 - val_loss: 0.4846 - val_accuracy: 0.7856
# Epoch 46/100
# 563/563 [==============================] - 7s 12ms/step - loss: 0.5028 - accuracy: 0.7954 - val_loss: 0.4950 - val_accuracy: 0.8181
# Epoch 47/100
# 563/563 [==============================] - 6s 12ms/step - loss: 0.4831 - accuracy: 0.7925 - val_loss: 0.4744 - val_accuracy: 0.8075
# Epoch 48/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.4880 - accuracy: 0.8048 - val_loss: 0.5559 - val_accuracy: 0.7483
# Epoch 49/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.5234 - accuracy: 0.7877 - val_loss: 0.4906 - val_accuracy: 0.7829
# Epoch 50/100
# 563/563 [==============================] - 4s 8ms/step - loss: 0.4974 - accuracy: 0.7940 - val_loss: 0.5249 - val_accuracy: 0.8267
# Epoch 51/100
# 563/563 [==============================] - 5s 8ms/step - loss: 0.4967 - accuracy: 0.7934 - val_loss: 0.5405 - val_accuracy: 0.7600
# Epoch 52/100
# 563/563 [==============================] - 5s 9ms/step - loss: 0.5118 - accuracy: 0.7975 - val_loss: 0.6932 - val_accuracy: 0.7019
# Epoch 53/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5076 - accuracy: 0.7956 - val_loss: 0.5026 - val_accuracy: 0.8197
# Epoch 54/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5502 - accuracy: 0.7941 - val_loss: 0.4820 - val_accuracy: 0.7952
# Epoch 55/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.4947 - accuracy: 0.8004 - val_loss: 0.4592 - val_accuracy: 0.8181
# Epoch 56/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.5294 - accuracy: 0.7902 - val_loss: 0.6060 - val_accuracy: 0.8283
# Epoch 57/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5294 - accuracy: 0.7936 - val_loss: 0.4508 - val_accuracy: 0.8091
# Epoch 58/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5051 - accuracy: 0.7902 - val_loss: 0.7153 - val_accuracy: 0.6949
# Epoch 59/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5208 - accuracy: 0.7920 - val_loss: 0.4416 - val_accuracy: 0.8171
# Epoch 60/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5271 - accuracy: 0.7950 - val_loss: 0.5549 - val_accuracy: 0.7509
# Epoch 61/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5189 - accuracy: 0.7959 - val_loss: 0.5191 - val_accuracy: 0.8192
# Epoch 62/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5983 - accuracy: 0.7845 - val_loss: 0.4689 - val_accuracy: 0.7899
# Epoch 63/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5442 - accuracy: 0.7902 - val_loss: 0.4535 - val_accuracy: 0.7979
# Epoch 64/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5594 - accuracy: 0.7906 - val_loss: 0.4864 - val_accuracy: 0.8101
# Epoch 65/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5477 - accuracy: 0.7916 - val_loss: 0.4612 - val_accuracy: 0.8080
# Epoch 66/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5461 - accuracy: 0.7938 - val_loss: 0.5687 - val_accuracy: 0.8251
# Epoch 67/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.5365 - accuracy: 0.7883 - val_loss: 0.5040 - val_accuracy: 0.7765
# Epoch 68/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5732 - accuracy: 0.7874 - val_loss: 0.5058 - val_accuracy: 0.7888
# Epoch 69/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5990 - accuracy: 0.7819 - val_loss: 0.6488 - val_accuracy: 0.7195
# Epoch 70/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.5331 - accuracy: 0.7948 - val_loss: 0.4829 - val_accuracy: 0.8069
# Epoch 71/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.5408 - accuracy: 0.7844 - val_loss: 0.8474 - val_accuracy: 0.6805
# Epoch 72/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5491 - accuracy: 0.7876 - val_loss: 0.5150 - val_accuracy: 0.8128
# Epoch 73/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.5900 - accuracy: 0.7888 - val_loss: 0.4689 - val_accuracy: 0.8069
# Epoch 74/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5743 - accuracy: 0.7861 - val_loss: 0.5434 - val_accuracy: 0.8085
# Epoch 75/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5565 - accuracy: 0.7863 - val_loss: 0.4473 - val_accuracy: 0.8149
# Epoch 76/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.5340 - accuracy: 0.7877 - val_loss: 0.5050 - val_accuracy: 0.7845
# Epoch 77/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.5608 - accuracy: 0.7884 - val_loss: 0.6291 - val_accuracy: 0.7941
# Epoch 78/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5944 - accuracy: 0.7819 - val_loss: 0.4498 - val_accuracy: 0.8069
# Epoch 79/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5550 - accuracy: 0.7858 - val_loss: 0.4717 - val_accuracy: 0.8064
# Epoch 80/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.6392 - accuracy: 0.7813 - val_loss: 0.4979 - val_accuracy: 0.7936
# Epoch 81/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5793 - accuracy: 0.7893 - val_loss: 0.5717 - val_accuracy: 0.7781
# Epoch 82/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.6035 - accuracy: 0.7799 - val_loss: 0.5435 - val_accuracy: 0.7829
# Epoch 83/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.5770 - accuracy: 0.7858 - val_loss: 1.0755 - val_accuracy: 0.7637
# Epoch 84/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.6045 - accuracy: 0.7812 - val_loss: 0.5403 - val_accuracy: 0.7621
# Epoch 85/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.5772 - accuracy: 0.7899 - val_loss: 0.9628 - val_accuracy: 0.7803
# Epoch 86/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.6413 - accuracy: 0.7820 - val_loss: 0.5480 - val_accuracy: 0.8288
# Epoch 87/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.6116 - accuracy: 0.7854 - val_loss: 0.6653 - val_accuracy: 0.7195
# Epoch 88/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.6259 - accuracy: 0.7737 - val_loss: 0.4875 - val_accuracy: 0.7979
# Epoch 89/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.6023 - accuracy: 0.7781 - val_loss: 0.7111 - val_accuracy: 0.7392
# Epoch 90/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.6497 - accuracy: 0.7824 - val_loss: 0.9228 - val_accuracy: 0.7877
# Epoch 91/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.6219 - accuracy: 0.7794 - val_loss: 0.4679 - val_accuracy: 0.7979
# Epoch 92/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5866 - accuracy: 0.7792 - val_loss: 0.4775 - val_accuracy: 0.8048
# Epoch 93/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.6156 - accuracy: 0.7835 - val_loss: 0.4952 - val_accuracy: 0.7920
# Epoch 94/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.6783 - accuracy: 0.7764 - val_loss: 0.7694 - val_accuracy: 0.7061
# Epoch 95/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5777 - accuracy: 0.7831 - val_loss: 0.4818 - val_accuracy: 0.7979
# Epoch 96/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.6251 - accuracy: 0.7764 - val_loss: 0.5638 - val_accuracy: 0.8165
# Epoch 97/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.5893 - accuracy: 0.7847 - val_loss: 0.4726 - val_accuracy: 0.8091
# Epoch 98/100
# 563/563 [==============================] - 6s 10ms/step - loss: 0.7183 - accuracy: 0.7728 - val_loss: 0.4793 - val_accuracy: 0.7979
# Epoch 99/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.6467 - accuracy: 0.7808 - val_loss: 0.6640 - val_accuracy: 0.8267
# Epoch 100/100
# 563/563 [==============================] - 6s 11ms/step - loss: 0.6186 - accuracy: 0.7831 - val_loss: 0.5862 - val_accuracy: 0.7248

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
y_pred = classifier.predict(X_test)
y_pred = (y_pred>0.5)
y_pred
# Out:
# 53/79 [===================>..........] - ETA: 0s
# 2023-08-13 13:02:49.862742: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 79/79 [==============================] - 0s 4ms/step
# array([[ True],
#        [False],
#        [ True],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1581,  401],
#        [ 256,  262]])

# %%
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.7372
